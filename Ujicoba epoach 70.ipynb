# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadthaufik10315/Deeplearning_Klasifikasi_Wajah_Moi_2-Efficientnet-/blob/main/Ujicoba%20epoach%2070.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U --pre efficientnet
from efficientnet.tfkeras import EfficientNetB1
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
import seaborn as sns
import tensorflow
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os
# Out:
# Requirement already satisfied: efficientnet in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.11.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (23.2)

# %%
IMAGE_WIDTH=224
IMAGE_HEIGHT=224
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %%
path = "/content/drive/MyDrive/split_data/suku7/train"
lists_dir = os.listdir(path)
categories = []
file_name = []
for folder in lists_dir:
    files = os.listdir(path +"/"+folder)
    for file in files:
        path_file = path + "/" + folder + "/" + file
        file_name.append(path_file)
        categories.append(folder)

df = {"image": file_name,"categories": categories}
data = pd.DataFrame(df, index = None)
data = data.sample(frac=1)
data.head(5)
# Out:
#                                                  image categories
# 102  /content/drive/MyDrive/split_data/suku7/train/...  rajaampat
# 221  /content/drive/MyDrive/split_data/suku7/train/...        moi
# 55   /content/drive/MyDrive/split_data/suku7/train/...  rajaampat
# 299  /content/drive/MyDrive/split_data/suku7/train/...        moi
# 301  /content/drive/MyDrive/split_data/suku7/train/...        moi

# %%
path_datatest = "/content/drive/MyDrive/split_data/suku7/test"
lists_dir_datatest = os.listdir(path_datatest)
categories_datatest = []
file_name_datatest = []
for folder in lists_dir_datatest:
    files = os.listdir(path_datatest +"/"+folder)
    for file in files:
        path_file = path_datatest + "/" + folder + "/" + file
        file_name_datatest.append(path_file)
        categories_datatest.append(folder)

df_datatest = {"image": file_name_datatest,"categories":categories_datatest}
data_datatest = pd.DataFrame(df_datatest, index = None)
data_datatest = data_datatest.sample(frac=1)
nb_samples=data_datatest.shape[0]
data_datatest
# Out:
#                                                  image categories
# 72   /content/drive/MyDrive/split_data/suku7/test/m...        moi
# 109  /content/drive/MyDrive/split_data/suku7/test/r...  rajaampat
# 137  /content/drive/MyDrive/split_data/suku7/test/r...  rajaampat
# 17   /content/drive/MyDrive/split_data/suku7/test/m...        moi
# 19   /content/drive/MyDrive/split_data/suku7/test/m...        moi
# ..                                                 ...        ...
# 37   /content/drive/MyDrive/split_data/suku7/test/m...        moi
# 148  /content/drive/MyDrive/split_data/suku7/test/r...  rajaampat
# 14   /content/drive/MyDrive/split_data/suku7/test/m...        moi
# 36   /content/drive/MyDrive/split_data/suku7/test/m...        moi
# 144  /content/drive/MyDrive/split_data/suku7/test/r...  rajaampat
#
# [160 rows x 2 columns]

# %%
data['categories'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
total_dataset=len(data_datatest)+len(data)
"Total dataset Suku :{} Suku".format(total_dataset)
# Out:
# 'Total dataset Suku :635 Suku'

# %%
data["categories"] = data["categories"].replace({0: 'MOI', 1: 'RAJA AMPAT'})

# %%
train_df, validate_df = train_test_split(data, test_size=0.10, random_state=30)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['categories'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
len(train_df)
# Out:
# 427

# %%
validate_df['categories'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
len(validate_df)
# Out:
# 48

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=32

# %%
train_datagen = ImageDataGenerator(
    rotation_range=30,
    rescale=1./255,
    shear_range=0.1,
    vertical_flip=True,
)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=path,
    x_col='image',
    y_col='categories',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 427 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe(
    dataframe=validate_df,
    directory=path,
    x_col='image',
    y_col='categories',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 48 validated image filenames belonging to 2 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    dataframe=example_df,
    dir=path,
    x_col='image',
    y_col='categories',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 10):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
base_model = EfficientNetB1(input_shape=(224,224,3),
                                 include_top=False,
                                 weights='noisy-student')

# %%
for layer in base_model.layers:
    layer.trainable=False

# %%
model = Sequential()
model.add(base_model)
model.add(Conv2D(640,kernel_size=(1,1)))
model.add(Flatten())
model.add(Dense(320,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(tensorflow.keras.layers.ReLU())
model.add(Dropout(0.2))
model.add(Dense(2,activation='softmax'))

# %%
model.compile("adam",loss="categorical_crossentropy",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnet-b1 (Functiona  (None, 7, 7, 1280)        6575232
#  l)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 640)         819840
#
#  flatten_2 (Flatten)         (None, 31360)             0
#
#  dense_4 (Dense)             (None, 320)               10035520
#
#  batch_normalization_2 (Bat  (None, 320)               1280
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 320)               0
#
#  dropout_2 (Dropout)         (None, 320)               0
#
#  dense_5 (Dense)             (None, 2)                 642
#
# =================================================================
# Total params: 17432514 (66.50 MB)
# Trainable params: 10856642 (41.41 MB)
# Non-trainable params: 6575872 (25.08 MB)
# _________________________________________________________________

# %%
epochs=70
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
)
# Out:
# Epoch 1/70
# 13/13 [==============================] - 23s 1s/step - loss: 1.4622 - accuracy: 0.6010 - val_loss: 4.7753 - val_accuracy: 0.5625
# Epoch 2/70
# 13/13 [==============================] - 10s 773ms/step - loss: 0.8239 - accuracy: 0.6861 - val_loss: 3.8313 - val_accuracy: 0.6250
# Epoch 3/70
# 13/13 [==============================] - 12s 910ms/step - loss: 0.5526 - accuracy: 0.8051 - val_loss: 5.1868 - val_accuracy: 0.5000
# Epoch 4/70
# 13/13 [==============================] - 12s 893ms/step - loss: 0.3946 - accuracy: 0.8278 - val_loss: 1.8836 - val_accuracy: 0.7188
# Epoch 5/70
# 13/13 [==============================] - 11s 862ms/step - loss: 0.4062 - accuracy: 0.8228 - val_loss: 1.3399 - val_accuracy: 0.7188
# Epoch 6/70
# 13/13 [==============================] - 12s 908ms/step - loss: 0.3086 - accuracy: 0.8709 - val_loss: 1.1731 - val_accuracy: 0.6875
# Epoch 7/70
# 13/13 [==============================] - 11s 886ms/step - loss: 0.3660 - accuracy: 0.8354 - val_loss: 0.6295 - val_accuracy: 0.7500
# Epoch 8/70
# 13/13 [==============================] - 11s 795ms/step - loss: 0.3800 - accuracy: 0.8456 - val_loss: 0.7835 - val_accuracy: 0.7188
# Epoch 9/70
# 13/13 [==============================] - 12s 920ms/step - loss: 0.3829 - accuracy: 0.8456 - val_loss: 0.5280 - val_accuracy: 0.8438
# Epoch 10/70
# 13/13 [==============================] - 11s 894ms/step - loss: 0.3317 - accuracy: 0.8456 - val_loss: 0.3110 - val_accuracy: 0.8750
# Epoch 11/70
# 13/13 [==============================] - 10s 783ms/step - loss: 0.2544 - accuracy: 0.8557 - val_loss: 0.7376 - val_accuracy: 0.7188
# Epoch 12/70
# 13/13 [==============================] - 11s 918ms/step - loss: 0.3196 - accuracy: 0.8684 - val_loss: 0.2608 - val_accuracy: 0.8438
# Epoch 13/70
# 13/13 [==============================] - 12s 903ms/step - loss: 0.2424 - accuracy: 0.8962 - val_loss: 0.9736 - val_accuracy: 0.7500
# Epoch 14/70
# 13/13 [==============================] - 11s 882ms/step - loss: 0.2665 - accuracy: 0.8911 - val_loss: 0.3948 - val_accuracy: 0.7812
# Epoch 15/70
# 13/13 [==============================] - 10s 763ms/step - loss: 0.2262 - accuracy: 0.9190 - val_loss: 0.5445 - val_accuracy: 0.7188
# Epoch 16/70
# 13/13 [==============================] - 12s 867ms/step - loss: 0.2508 - accuracy: 0.9013 - val_loss: 0.2801 - val_accuracy: 0.8750
# Epoch 17/70
# 13/13 [==============================] - 12s 940ms/step - loss: 0.2210 - accuracy: 0.9013 - val_loss: 0.2327 - val_accuracy: 0.9062
# Epoch 18/70
# 13/13 [==============================] - 12s 960ms/step - loss: 0.1896 - accuracy: 0.9139 - val_loss: 0.5740 - val_accuracy: 0.8438
# Epoch 19/70
# 13/13 [==============================] - 12s 903ms/step - loss: 0.2000 - accuracy: 0.9241 - val_loss: 0.5735 - val_accuracy: 0.8125
# Epoch 20/70
# 13/13 [==============================] - 12s 939ms/step - loss: 0.2445 - accuracy: 0.8937 - val_loss: 0.4662 - val_accuracy: 0.8125
# Epoch 21/70
# 13/13 [==============================] - 12s 903ms/step - loss: 0.2389 - accuracy: 0.9063 - val_loss: 0.3056 - val_accuracy: 0.8750
# Epoch 22/70
# 13/13 [==============================] - 12s 887ms/step - loss: 0.1732 - accuracy: 0.9215 - val_loss: 0.4408 - val_accuracy: 0.8438
# Epoch 23/70
# 13/13 [==============================] - 12s 948ms/step - loss: 0.1974 - accuracy: 0.9038 - val_loss: 0.4011 - val_accuracy: 0.8438
# Epoch 24/70
# 13/13 [==============================] - 12s 968ms/step - loss: 0.2275 - accuracy: 0.9013 - val_loss: 0.3647 - val_accuracy: 0.9062
# Epoch 25/70
# 13/13 [==============================] - 12s 903ms/step - loss: 0.1981 - accuracy: 0.9139 - val_loss: 0.2398 - val_accuracy: 0.9375
# Epoch 26/70
# 13/13 [==============================] - 12s 928ms/step - loss: 0.1772 - accuracy: 0.9190 - val_loss: 0.2287 - val_accuracy: 0.9375
# Epoch 27/70
# 13/13 [==============================] - 12s 915ms/step - loss: 0.2111 - accuracy: 0.9087 - val_loss: 0.4519 - val_accuracy: 0.8125
# Epoch 28/70
# 13/13 [==============================] - 10s 774ms/step - loss: 0.1824 - accuracy: 0.9392 - val_loss: 0.2721 - val_accuracy: 0.8750
# Epoch 29/70
# 13/13 [==============================] - 11s 818ms/step - loss: 0.2207 - accuracy: 0.8987 - val_loss: 0.2475 - val_accuracy: 0.8438
# Epoch 30/70
# 13/13 [==============================] - 12s 916ms/step - loss: 0.1752 - accuracy: 0.9367 - val_loss: 0.5150 - val_accuracy: 0.8125
# Epoch 31/70
# 13/13 [==============================] - 12s 895ms/step - loss: 0.2189 - accuracy: 0.9165 - val_loss: 0.5186 - val_accuracy: 0.7812
# Epoch 32/70
# 13/13 [==============================] - 10s 782ms/step - loss: 0.1985 - accuracy: 0.9139 - val_loss: 0.5097 - val_accuracy: 0.7500
# Epoch 33/70
# 13/13 [==============================] - 11s 817ms/step - loss: 0.1743 - accuracy: 0.9266 - val_loss: 0.7836 - val_accuracy: 0.7500
# Epoch 34/70
# 13/13 [==============================] - 12s 911ms/step - loss: 0.1603 - accuracy: 0.9291 - val_loss: 1.5097 - val_accuracy: 0.5312
# Epoch 35/70
# 13/13 [==============================] - 11s 925ms/step - loss: 0.1832 - accuracy: 0.9392 - val_loss: 0.3262 - val_accuracy: 0.8438
# Epoch 36/70
# 13/13 [==============================] - 10s 783ms/step - loss: 0.1687 - accuracy: 0.9392 - val_loss: 0.5583 - val_accuracy: 0.7812
# Epoch 37/70
# 13/13 [==============================] - 11s 806ms/step - loss: 0.2169 - accuracy: 0.9013 - val_loss: 0.3529 - val_accuracy: 0.9375
# Epoch 38/70
# 13/13 [==============================] - 11s 867ms/step - loss: 0.1280 - accuracy: 0.9595 - val_loss: 0.3092 - val_accuracy: 0.8750
# Epoch 39/70
# 13/13 [==============================] - 10s 721ms/step - loss: 0.1595 - accuracy: 0.9418 - val_loss: 0.2246 - val_accuracy: 0.8438
# Epoch 40/70
# 13/13 [==============================] - 11s 865ms/step - loss: 0.1207 - accuracy: 0.9544 - val_loss: 0.3676 - val_accuracy: 0.8438
# Epoch 41/70
# 13/13 [==============================] - 12s 915ms/step - loss: 0.1039 - accuracy: 0.9620 - val_loss: 0.2353 - val_accuracy: 0.9062
# Epoch 42/70
# 13/13 [==============================] - 11s 817ms/step - loss: 0.1226 - accuracy: 0.9519 - val_loss: 0.1918 - val_accuracy: 0.8750
# Epoch 43/70
# 13/13 [==============================] - 12s 907ms/step - loss: 0.1451 - accuracy: 0.9519 - val_loss: 0.2737 - val_accuracy: 0.8750
# Epoch 44/70
# 13/13 [==============================] - 12s 903ms/step - loss: 0.0959 - accuracy: 0.9671 - val_loss: 0.2191 - val_accuracy: 0.9062
# Epoch 45/70
# 13/13 [==============================] - 11s 826ms/step - loss: 0.1218 - accuracy: 0.9620 - val_loss: 0.3703 - val_accuracy: 0.8125
# Epoch 46/70
# 13/13 [==============================] - 12s 915ms/step - loss: 0.1167 - accuracy: 0.9494 - val_loss: 0.4043 - val_accuracy: 0.8750
# Epoch 47/70
# 13/13 [==============================] - 11s 867ms/step - loss: 0.1004 - accuracy: 0.9570 - val_loss: 0.1530 - val_accuracy: 0.9375
# Epoch 48/70
# 13/13 [==============================] - 11s 824ms/step - loss: 0.0839 - accuracy: 0.9671 - val_loss: 0.3646 - val_accuracy: 0.8750
# Epoch 49/70
# 13/13 [==============================] - 11s 879ms/step - loss: 0.0940 - accuracy: 0.9544 - val_loss: 0.6475 - val_accuracy: 0.8125
# Epoch 50/70
# 13/13 [==============================] - 10s 766ms/step - loss: 0.0933 - accuracy: 0.9620 - val_loss: 0.4339 - val_accuracy: 0.9062
# Epoch 51/70
# 13/13 [==============================] - 11s 849ms/step - loss: 0.1134 - accuracy: 0.9544 - val_loss: 0.4597 - val_accuracy: 0.8125
# Epoch 52/70
# 13/13 [==============================] - 11s 880ms/step - loss: 0.1349 - accuracy: 0.9595 - val_loss: 0.4060 - val_accuracy: 0.7812
# Epoch 53/70
# 13/13 [==============================] - 11s 859ms/step - loss: 0.1495 - accuracy: 0.9367 - val_loss: 0.5625 - val_accuracy: 0.8438
# Epoch 54/70
# 13/13 [==============================] - 11s 886ms/step - loss: 0.1237 - accuracy: 0.9443 - val_loss: 0.3609 - val_accuracy: 0.8750
# Epoch 55/70
# 13/13 [==============================] - 11s 877ms/step - loss: 0.1536 - accuracy: 0.9367 - val_loss: 0.3108 - val_accuracy: 0.8750
# Epoch 56/70
# 13/13 [==============================] - 10s 812ms/step - loss: 0.1530 - accuracy: 0.9443 - val_loss: 0.3572 - val_accuracy: 0.8438
# Epoch 57/70
# 13/13 [==============================] - 12s 914ms/step - loss: 0.1390 - accuracy: 0.9494 - val_loss: 0.1895 - val_accuracy: 0.9375
# Epoch 58/70
# 13/13 [==============================] - 12s 916ms/step - loss: 0.1244 - accuracy: 0.9544 - val_loss: 0.2439 - val_accuracy: 0.9062
# Epoch 59/70
# 13/13 [==============================] - 10s 788ms/step - loss: 0.1013 - accuracy: 0.9671 - val_loss: 0.3484 - val_accuracy: 0.8750
# Epoch 60/70
# 13/13 [==============================] - 11s 885ms/step - loss: 0.0822 - accuracy: 0.9620 - val_loss: 0.4635 - val_accuracy: 0.8125
# Epoch 61/70
# 13/13 [==============================] - 10s 796ms/step - loss: 0.1290 - accuracy: 0.9443 - val_loss: 0.6351 - val_accuracy: 0.8438
# Epoch 62/70
# 13/13 [==============================] - 11s 871ms/step - loss: 0.0956 - accuracy: 0.9696 - val_loss: 0.2409 - val_accuracy: 0.9062
# Epoch 63/70
# 13/13 [==============================] - 11s 878ms/step - loss: 0.1053 - accuracy: 0.9696 - val_loss: 0.8456 - val_accuracy: 0.7500
# Epoch 64/70
# 13/13 [==============================] - 10s 777ms/step - loss: 0.0734 - accuracy: 0.9671 - val_loss: 0.8850 - val_accuracy: 0.8125
# Epoch 65/70
# 13/13 [==============================] - 11s 819ms/step - loss: 0.1128 - accuracy: 0.9544 - val_loss: 0.2848 - val_accuracy: 0.8750
# Epoch 66/70
# 13/13 [==============================] - 12s 902ms/step - loss: 0.0884 - accuracy: 0.9671 - val_loss: 0.2135 - val_accuracy: 0.8438
# Epoch 67/70
# 13/13 [==============================] - 12s 906ms/step - loss: 0.0783 - accuracy: 0.9663 - val_loss: 0.1713 - val_accuracy: 0.9062
# Epoch 68/70
# 13/13 [==============================] - 11s 886ms/step - loss: 0.1339 - accuracy: 0.9544 - val_loss: 0.3822 - val_accuracy: 0.8125
# Epoch 69/70
# 13/13 [==============================] - 11s 779ms/step - loss: 0.0900 - accuracy: 0.9696 - val_loss: 0.2897 - val_accuracy: 0.8750
# Epoch 70/70
# 13/13 [==============================] - 12s 904ms/step - loss: 0.1004 - accuracy: 0.9519 - val_loss: 0.2004 - val_accuracy: 0.9062

# %%
plt.plot(history.history["accuracy"],label="Akurasi Pelatihan")
plt.plot(history.history["val_accuracy"],label="Validasi Akurasi")
plt.legend()
plt.show()

plt.plot(history.history["loss"],label="Kesalahan Pelatihan")
plt.plot(history.history["val_loss"],label="Validasi Kesalahan")
plt.legend()
plt.show()

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    dataframe=data_datatest,
    dir=path_datatest,
    x_col='image',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 160 validated image filenames.

# %%
predict = model.predict(test_generator, steps=np.ceil(nb_samples/batch_size))
# Out:
# 5/5 [==============================] - 2s 126ms/step

# %%
predicted_classes=np.argmax(predict,axis=1)
predicted_classes

# %%
true_classes=np.array(data_datatest['categories'].replace(['moi','rajaampat',],[0,1]))
true_classes

# %%
class_labels=['0','1']
class_labels

# %%
cm = confusion_matrix(true_classes, predicted_classes)
cm
# Out:
# array([[67, 23],
#        [29, 41]])

# %%
cm_df = pd.DataFrame(cm,
                     index = ['moi','rajaampat'],
                     columns = ['moi','rajaampat'])

plt.figure(figsize=(8,8))
sns.heatmap(cm_df, annot=True)
plt.title('CNN EfficientNet-B1 \nAccuracy:{0:.3f}'.format(accuracy_score(true_classes, predicted_classes)))
plt.ylabel('Label Sebenarnya')
plt.xlabel('Label Prediksi')
plt.show()

# %%
report=metrics.classification_report(true_classes, predicted_classes,target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72        90
#            1       0.64      0.59      0.61        70
#
#     accuracy                           0.68       160
#    macro avg       0.67      0.67      0.67       160
# weighted avg       0.67      0.68      0.67       160

# %%
import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open("model.tflite", "wb") as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:`efficientnet-b1_input` is not a valid tf.function parameter name. Sanitizing to `efficientnet_b1_input`.
# WARNING:absl:`efficientnet-b1_input` is not a valid tf.function parameter name. Sanitizing to `efficientnet_b1_input`.
